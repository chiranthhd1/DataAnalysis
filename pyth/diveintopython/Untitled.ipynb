# %%
import Quandl as q

# %%
myd = q.get("GOOG/BOM_500014")

# %%
myd
# Out:
#             Open  High   Low  Close  Volume
# Date
# 2012-11-26  1.85  2.01  1.85   1.99   12470
# 2012-11-27  2.00  2.03  1.93   2.01    6065
# 2012-11-29  2.07  2.10  1.96   2.01   11996
# 2012-11-30  1.97  2.02  1.95   2.01    8941
# 2012-12-03  1.99  2.00  1.99   1.99    4300
# 2012-12-04  2.04  2.07  1.97   2.02    8380
# 2012-12-05  2.12  2.12  1.93   1.99   18809
# 2012-12-06  2.00  2.08  1.84   2.03    5284
# 2012-12-07  2.04  2.04  1.94   2.04    4813
# 2012-12-10  2.12  2.12  1.97   2.10   16649
# 2012-12-11  1.71  2.14  1.71   2.05   11953
# 2012-12-12  2.05  2.09  1.85   2.02   33043
# 2012-12-13  2.08  2.08  1.96   2.01    6011
# 2012-12-14  2.05  2.05  1.94   1.94    4975
# 2012-12-17  1.99  1.99  1.87   1.90   12053
# 2012-12-18  1.94  1.97  1.87   1.95    7988
# 2012-12-19  2.00  2.00  1.92   2.00   11445
# 2012-12-20  2.03  2.03  1.93   1.95    6819
# 2012-12-21  1.99  2.04  1.86   1.99   39264
# 2012-12-24  1.99  1.99  1.91   1.98    5960
# ...

# %%
myd1 = q.get("GOOG/NYSE_INR")

# %%
myd1
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2008-03-19  40.39  40.40  40.36  40.36    5300
# 2008-03-20  40.36  40.36  40.36  40.36     100
# 2008-03-24  40.65  40.65  40.65  40.65     200
# 2008-03-25  40.70  40.70  40.63  40.63    1100
# 2008-03-26  40.72  40.72  40.72  40.72    1100
# 2008-03-27  40.83  40.88  40.81  40.82   14500
# 2008-03-28  41.17  41.20  41.12  41.20   17300
# 2008-03-31  40.90  40.90  40.88  40.88   17000
# 2008-04-01    NaN    NaN    NaN  40.88       0
# 2008-04-02  41.27  41.27  41.27  41.27     100
# 2008-04-03  40.97  41.08  40.97  41.08     200
# 2008-04-04  41.02  41.05  41.02  41.05     400
# 2008-04-07  41.03  41.03  41.03  41.03    1700
# 2008-04-08  40.96  40.99  40.96  40.99     600
# 2008-04-09  41.00  41.04  41.00  41.04    4600
# 2008-04-10  41.05  41.12  41.03  41.08    2500
# 2008-04-11  41.15  41.15  41.14  41.14     200
# 2008-04-14  41.12  41.12  41.07  41.12    5500
# 2008-04-15  41.12  41.12  40.95  41.07    2300
# ...

# %%
import Qaundl as q
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-95dc17ade8fb> in <module>()
# ----> 1 import Qaundl as q
#
# ImportError: No module named Qaundl

# %%
myd3 = q.get("CUR/INR")
# Out:
# ---------------------------------------------------------------------------
# CallLimitExceeded                         Traceback (most recent call last)
# <ipython-input-8-ff608ab17df9> in <module>()
# ----> 1 myd3 = q.get("CUR/INR")
#
# /home/chiranth/anaconda2/lib/python2.7/site-packages/Quandl/Quandl.pyc in get(dataset, **kwargs)
#     126         if str(e) == 'HTTP Error 403: Forbidden':
#     127             error = 'API daily call limit exceeded. Contact us at connect@quandl.com if you want an increased daily limit'
# --> 128             raise CallLimitExceeded(error)
#     129
#     130         #Dataset not found
#
# CallLimitExceeded: API daily call limit exceeded. Contact us at connect@quandl.com if you want an increased daily limit

# %%
myd3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7e0d8eff3e4a> in <module>()
# ----> 1 myd3
#
# NameError: name 'myd3' is not defined

# %%
import Qaundl as q
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-95dc17ade8fb> in <module>()
# ----> 1 import Qaundl as q
#
# ImportError: No module named Qaundl
